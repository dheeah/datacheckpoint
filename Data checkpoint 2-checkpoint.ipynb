# %%
link = "https://github.com/dheeah/dataset/blob/main/titanic-passengers.csv"
print(link.replace("github.com", "raw.githubusercontent.com").replace("/blob/", "/"))
# Out:
# https://raw.githubusercontent.com/dheeah/dataset/main/titanic-passengers.csv

# %%
import requests

download_url = "https://raw.githubusercontent.com/dheeah/dataset/main/titanic-passengers.csv"
target_csv_path = "titanic_passengers.csv"

response = requests.get(download_url)
response.raise_for_status()    
with open(target_csv_path, "wb") as f:
    f.write(response.content)
print("Download ready.")
# Out:
# Download ready.

# %%
import pandas as pd
titanic_passengers = pd.read_csv("titanic_passengers.csv", sep=';')
type(titanic_passengers)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_csv('titanic_passengers.csv', index_col=0, sep=';')
df
# Out:
#             Survived  Pclass  \
# PassengerId
# 343               No       2
# 76                No       3
# 641               No       3
# 568               No       3
# 672               No       1
# ...              ...     ...
# 10               Yes       2
# 61                No       3
# 535               No       3
# 102               No       3
# 428              Yes       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 343                                 Collander, Mr. Erik Gustaf    male  28.0
# 76                                     Moen, Mr. Sigurd Hansen    male  25.0
# 641                                     Jensen, Mr. Hans Peder    male  20.0
# 568                Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0
# 672                                     Davidson, Mr. Thornton    male  31.0
# ...                                                        ...     ...   ...
# ...

# %%
df = pd.DataFrame(titanic_passengers, columns=['PassengerId', 'Survived',
                                     'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'])

# %%
len(titanic_passengers)
# Out:
# 891

# %%
titanic_passengers.shape
# Out:
# (891, 12)

# %%
titanic_passengers.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
pd.set_option("display.max.columns", None)

# %%
pd.set_option("display.precision", 2)

# %%
titanic_passengers.tail()
# Out:
#      PassengerId Survived  Pclass  \
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 886      0  237736  30.07   NaN        C
# 887      0    2669   7.23   NaN        C
# 888      0  315084   8.66   NaN        S
# 889      0  349215   7.90   NaN        S
# 890      0  250655  26.00   NaN        S

# %%
titanic_passengers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
titanic_passengers.describe()
# Out:
#        PassengerId  Pclass     Age   SibSp   Parch    Fare
# count       891.00  891.00  714.00  891.00  891.00  891.00
# mean        446.00    2.31   29.70    0.52    0.38   32.20
# std         257.35    0.84   14.53    1.10    0.81   49.69
# min           1.00    1.00    0.42    0.00    0.00    0.00
# 25%         223.50    2.00   20.12    0.00    0.00    7.91
# 50%         446.00    3.00   28.00    0.00    0.00   14.45
# 75%         668.50    3.00   38.00    1.00    0.00   31.00
# max         891.00    3.00   80.00    8.00    6.00  512.33

# %%
import numpy as np
titanic_passengers.describe(include=object)
# Out:
#        Survived                Name   Sex    Ticket    Cabin Embarked
# count       891                 891   891       891      204      889
# unique        2                 891     2       681      147        3
# top          No  Niskanen, Mr. Juha  male  CA. 2343  B96 B98        S
# freq        549                   1   577         7        4      644

# %%
titanic_passengers["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
titanic_passengers["Age"].value_counts()
# Out:
# 24.0    30
# 22.0    27
# 18.0    26
# 30.0    25
# 28.0    25
#         ..
# 23.5     1
# 55.5     1
# 70.5     1
# 74.0     1
# 12.0     1
# Name: Age, Length: 88, dtype: int64

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
titanic = sns.load_dataset("titanic")
ax = sns.countplot(x="class", data=titanic)

# %%
sns.countplot(x='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Sex',data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.countplot(x='Pclass',data=df)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
ax = sns.countplot(y="class", hue="who", data=titanic)

# %%
ax = sns.countplot(x="who", data=titanic, palette="Set3")

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\msi\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.countplot(x='Age',hue='Sex',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.countplot(y='Age',hue='Sex',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Age'>

# %%
sns.countplot(x='Sex',hue='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.countplot(y='Sex',hue='Age',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Sex'>

# %%
sns.countplot(x='Survived',hue='Pclass',data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Pclass',hue='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
sns.boxplot(data=df, x='Sex', y='Age')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
sns.barplot(x='Survived',y="Pclass",data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Pclass'>

# %%
sns.boxplot(data=df, x='Age', y='Sex', hue ='Survived')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Sex'>

# %%
cor = df.corr()
sns.heatmap(cor)
# Out:
# <AxesSubplot:>

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )
    #This function is used to make the data more fancy and more accurate.

# %%
titanic_passengers.drop('Name',
  axis='columns', inplace=True)

# %%
titanic_passengers["Name"].str.len()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-3e13aae54b46> in <module>
# ...

# %%
titanic_passengers.tail()
# Out:
#      PassengerId Survived  Pclass     Sex   Age  SibSp  Parch  Ticket   Fare  \
# 886           10      Yes       2  female  14.0      1      0  237736  30.07
# 887           61       No       3    male  22.0      0      0    2669   7.23
# 888          535       No       3  female  30.0      0      0  315084   8.66
# 889          102       No       3    male   NaN      0      0  349215   7.90
# 890          428      Yes       2  female  19.0      0      0  250655  26.00
#
#     Cabin Embarked
# 886   NaN        C
# 887   NaN        C
# 888   NaN        S
# 889   NaN        S
# 890   NaN        S
